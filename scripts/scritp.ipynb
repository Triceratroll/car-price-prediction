# %%
#Importing the basic librarires fot analysis

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('coches-de-segunda-mano-sample.csv')
cars = df.dropna() 
cars['make'].unique()
# Out:
# array(['FORD', 'PEUGEOT', 'LAND-ROVER', 'CITROEN', 'SKODA', 'BMW', 'OPEL',
#        'VOLVO', 'MITSUBISHI', 'FIAT', 'RENAULT', 'KIA', 'SEAT',
#        'MERCEDES-BENZ', 'DACIA', 'AUDI', 'VOLKSWAGEN', 'NISSAN', 'JEEP',
#        'SUZUKI', 'SSANGYONG', 'ABARTH', 'SMART', 'TOYOTA', 'HYUNDAI',
#        'MINI', 'MAZDA', 'PORSCHE', 'DS', 'CHEVROLET', 'INFINITI',
#        'ALFA ROMEO', 'LEXUS', 'TESLA', 'JAGUAR', 'HONDA', 'SUBARU',
#        'DODGE', 'MASERATI', 'ISUZU', 'LANCIA', 'CUPRA', 'DFSK',
#        'MAHINDRA', 'TATA', 'CHRYSLER', 'CADILLAC', 'ASTON MARTIN',
#        'IVECO', 'FERRARI', 'BENTLEY', 'LAMBORGHINI', 'SAAB', 'MAXUS',
#        'PIAGGIO', 'ROVER', 'DAEWOO'], dtype=object)

# %%
cars['make'].nunique()
# Out:
# 57

# %%
cars['model'].unique()
# Out:
# array(['Transit Connect', 'Transit', '3008', 'Discovery Sport',
#        'Berlingo', 'Octavia', 'C-Max', 'C3', 'Serie 1', 'Astra', 'XC60',
#        'ASX', 'Focus', '500L', 'S-MAX', 'Captur', '508 Hybrid', '308',
#        'XCeed', 'Insignia', 'Clio', 'Rifter', 'Crossland X', 'León',
#        'Clase E', 'Mégane', 'Clase V', 'Duster', 'A4', '5008',
#        'GLC Coupé', 'X3', 'Golf', 'i3', 'Fiesta', 'JUKE', 'Renegade',
#        'Swift', 'CLA', 'Serie 5', 'Arona', 'Rodius', 'Koleos', '500',
#        'Clase A', 'Vivaro', 'TT', 'fortwo', 'Tiguan', 'A3', 'Yaris',
#        'Polo', 'Q2', 'ceed', 'Tipo', 'Touran', 'C4 Spacetourer', 'Caddy',
#        'Auris', 'QASHQAI', '208', 'Korando', 'TUCSON', 'Mokka X', 'X6',
#        'Jumpy', 'C5 Aircross', 'A1', 'Focus C-MAX', '206 +', 'Serie 4',
#        'Ateca', 'Grandland X', 'i20', '508', 'X1', 'V40', 'Grand Scénic',
#        'Boxer', 'i30', 'Kangoo Furgón', 'Clase C', 'Serie 2 Gran Tourer',
# ...

# %%
cars['color'].unique()
# Out:
# array(['Blanco', 'Gris / Plata', 'Negro', ..., 'Gris / Plata (champagne)',
#        'Blanco (ICE WHITE SOLID)', 'Gris / Plata (PLATA PERLA)'],
#       dtype=object)

# %%
cars['color'].nunique()
# Out:
# 3565

# %%
cars.loc[cars['color'] == 'Amarillo']
# Out:
#                                     url                           company  \
# 455    f651d2fbd82f3efd59555caa93de979a  9881bcdd5a0ad4733037b3fb25e69c3a
# 469    d988b8f99d6757295a70f19d9f9995c6  9881bcdd5a0ad4733037b3fb25e69c3a
# 691    f4df9bbae3954f4981a831e542525c10  9881bcdd5a0ad4733037b3fb25e69c3a
# 766    a47a115fb574a181cb66db04fef87c83  9881bcdd5a0ad4733037b3fb25e69c3a
# 1046   17ba7e1e73137290d08239971d866e9e  9881bcdd5a0ad4733037b3fb25e69c3a
# ...                                 ...                               ...
# 46968  911f34b785d7a8940ba4195088dca3a4  9881bcdd5a0ad4733037b3fb25e69c3a
# 47099  9c803c7afe1872924f7a915416f62f9f  9881bcdd5a0ad4733037b3fb25e69c3a
# 48236  8e9b1b45407d154874c7f02ac58f6807  9881bcdd5a0ad4733037b3fb25e69c3a
# 48700  486422099b57cc0b8e3a3eaaf1ce68fb  9881bcdd5a0ad4733037b3fb25e69c3a
# 49787  f74287eb942354a95def1aa8f0cef826  9881bcdd5a0ad4733037b3fb25e69c3a
#
#                 make    model  \
# 455          PEUGEOT      208
# ...
